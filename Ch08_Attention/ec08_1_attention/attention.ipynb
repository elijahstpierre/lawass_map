# %% [markdown]
# # Understanding Attention
#
# <div style="background-color: #f0f8ff; border: 2px solid #4682b4; padding: 10px;">
# <a href="https://colab.research.google.com/github/DeepTrackAI/DeepLearningCrashCourse/blob/main/Ch08_Attention/ec08_1_attention/attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# <strong>If using Colab/Kaggle:</strong> You need to uncomment the code in the cell below this one.
# </div>

# %%
 # !pip install contractions deeplay spacy  # Uncomment if using Colab/Kaggle.
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting deeplay
#   Downloading deeplay-0.1.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (3.8.14)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from deeplay) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from deeplay) (3.10.0)
# Requirement already satisfied: torch>2.3 in /usr/local/lib/python3.12/dist-packages (from deeplay) (2.11.0+cpu)
# Collecting lightning (from deeplay)
#   Downloading lightning-2.6.5-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.8 MB/s eta 0:00:00
# Collecting torchmetrics (from deeplay)
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.26.0+cpu)
# Collecting torch-geometric (from deeplay)
#   Downloading torch_geometric-2.8.0.post1-py3-none-any.whl.metadata (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 2.7 MB/s eta 0:00:00
# Collecting kornia (from deeplay)
#   Downloading kornia-0.8.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from deeplay) (1.16.3)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.25.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from deeplay) (13.9.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from deeplay) (0.3.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in /usr/local/lib/python3.12/dist-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in /usr/local/lib/python3.12/dist-packages (from spacy) (1.3.3)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (0.26.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (4.67.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.32.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from spacy) (26.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2026.6.17)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (3.29.7)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (3.6.1)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>2.3->deeplay) (2025.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->deeplay) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->deeplay) (2.20.0)
# Requirement already satisfied: cloudpathlib>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.0)
# Requirement already satisfied: httpx>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.28.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->spacy) (3.0.3)
# Collecting kornia-rs>=0.1.9 (from kornia->deeplay)
#   Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: PyYAML<8.0,>5.4 in /usr/local/lib/python3.12/dist-packages (from lightning->deeplay) (6.0.3)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning->deeplay)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting pytorch-lightning (from lightning->deeplay)
#   Downloading pytorch_lightning-2.6.5-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->deeplay) (2.9.0.post0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->deeplay) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->deeplay) (2026.4.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->deeplay) (0.5)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (3.14.1)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (5.9.5)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric->deeplay) (3.8.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric->deeplay) (1.24.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.24.0->weasel<2.0.0,>=1.0.0->spacy) (0.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->deeplay) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->deeplay) (1.17.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=5.2.1->weasel<2.0.0,>=1.0.0->spacy) (2.2.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>2.3->deeplay) (1.3.0)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading deeplay-0.1.4-py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.7/176.7 kB 9.0 MB/s eta 0:00:00
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading kornia-0.8.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.7 MB/s eta 0:00:00
# Downloading lightning-2.6.5-py3-none-any.whl (848 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 848.6/848.6 kB 38.9 MB/s eta 0:00:00
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 22.3 MB/s eta 0:00:00
# Downloading torch_geometric-2.8.0.post1-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 29.6 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.14-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 64.2 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 19.0 MB/s eta 0:00:00
# Downloading pyahocorasick-2.3.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.1 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.5-py3-none-any.whl (852 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 852.4/852.4 kB 22.5 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, lightning-utilities, kornia-rs, anyascii, textsearch, torchmetrics, torch-geometric, kornia, contractions, pytorch-lightning, lightning, deeplay
# Successfully installed anyascii-0.3.3 contractions-0.1.73 deeplay-0.1.4 kornia-0.8.3 kornia-rs-0.1.14 lightning-2.6.5 lightning-utilities-0.15.3 pyahocorasick-2.3.1 pytorch-lightning-2.6.5 textsearch-0.0.24 torch-geometric-2.8.0.post1 torchmetrics-1.9.0

# %% [markdown]
# This notebook provides a complete code example that demonstrates how the attention mechanism works.

# %% [markdown]
# <div style="background-color: #f0f8ff; border: 2px solid #4682b4; padding: 10px;">
# <strong>Note:</strong> This notebook contains the Code Example 8-1 from the book
#
# **Deep Learning Crash Course**
# Giovanni Volpe, Benjamin Midtvedt, Jesús Pineda, Henrik Klein Moberg, Harshith Bachimanchi, Joana B. Pereira, Carlo Manzo
# No Starch Press, San Francisco (CA), 2026
# ISBN-13: 9781718503922
#
# [https://nostarch.com/deep-learning-crash-course](https://nostarch.com/deep-learning-crash-course)
#
# You can find the other notebooks on the [Deep Learning Crash Course GitHub page](https://github.com/DeepTrackAI/DeepLearningCrashCourse).
# </div>

# %% [markdown]
# ## Obtaining a Matrix Representation of Sentences
#
# Start by writing two sentences ...

# %%
query_sentence = "The teacher praised a student because she improved"
key_sentence = "A student asked the teacher to help her improve"

# %% [markdown]
# ... tokenize the two sentences ...

# %%
query_tokens = query_sentence.split()
key_tokens = key_sentence.split()

# %% [markdown]
# ... print the tokens ...

# %%
print(query_tokens)
print(key_tokens)
# Out:
# ['The', 'teacher', 'praised', 'a', 'student', 'because', 'she', 'improved']
# ['A', 'student', 'asked', 'the', 'teacher', 'to', 'help', 'her', 'improve']

# %% [markdown]
# ... download the GloVe embeddings ...

# %%
import os
from torchvision.datasets.utils import download_url, extract_archive

glove_folder = ".glove_cache"
if not os.path.exists(glove_folder):
    os.makedirs(glove_folder, exist_ok=True)
    url = "https://nlp.stanford.edu/data/glove.42B.300d.zip"
    download_url(url, glove_folder)
    zip_filepath = os.path.join(glove_folder, "glove.42B.300d.zip")
    extract_archive(zip_filepath, glove_folder)
    os.remove(zip_filepath)
# Out:
# 100%|██████████| 1.88G/1.88G [06:05<00:00, 5.13MB/s]

# %% [markdown]
# ... implement a function to load the GloVe embeddings ...

# %%
def load_glove_embeddings(glove_file):
    """Load GloVe embeddings."""
    glove_embeddings = {}
    with open(glove_file, "r", encoding="utf-8") as file:
        for line in file:
            values = line.split()
            word = values[0]
            glove_embeddings[word] = np.round(
                np.asarray(values[1:], dtype="float32"), decimals=6,
            )
    return glove_embeddings

# %% [markdown]
# ... implement a function to get GloVe embeddings for a vocabulary ...

# %%
def get_glove_embeddings(vocab, glove_embeddings, embed_dim):
    """Get GloVe embeddings for a vocabulary."""
    embeddings = torch.zeros((len(vocab), embed_dim), dtype=torch.float32)
    for i, token in enumerate(vocab):
        embedding = glove_embeddings.get(token)
        if embedding is None:
            embedding = glove_embeddings.get(token.lower())
        if embedding is not None:
            embeddings[i] = torch.tensor(embedding, dtype=torch.float32)
    return embeddings

# %% [markdown]
# ... calculate the embeddings of the query and key sentences ...

# %%
import numpy as np
import torch

glove_file = os.path.join(glove_folder, "glove.42B.300d.txt")
glove_embed, embed_dim = load_glove_embeddings(glove_file), 300

query_embeddings = get_glove_embeddings(query_tokens, glove_embed, embed_dim)
key_embeddings = get_glove_embeddings(key_tokens, glove_embed, embed_dim)

# %% [markdown]
# ... and print them out.

# %%
print(query_embeddings)
print(key_embeddings)
# Out:
# tensor([[-0.2084, -0.1493, -0.0175,  ..., -0.5407,  0.2120, -0.0094],
#         [ 0.3659,  0.1827, -0.2922,  ...,  0.1551,  0.4864,  0.3274],
#         [ 0.1378,  0.4019,  0.0804,  ...,  0.1261,  0.5996,  0.5268],
#         ...,
#         [ 0.1013, -0.1351, -0.2975,  ...,  0.0224,  0.2362,  0.1049],
#         [-0.0079,  0.4521, -0.3142,  ..., -0.1546,  0.3127,  0.2481],
#         [-0.0133,  0.0232,  0.1770,  ...,  0.0170,  0.2138,  0.1573]])
# tensor([[-0.0358,  0.7784, -0.5181,  ...,  0.0223, -0.3159, -0.3561],
#         [ 0.3523, -0.0145, -0.2560,  ...,  0.1641,  0.3485, -0.1979],
#         [-0.1269, -0.4053, -0.1072,  ...,  0.1691,  0.6001, -0.1345],
#         ...,
#         [-0.0088,  0.4015,  0.2687,  ...,  0.2388,  0.3528, -0.2538],
#         [-0.0932,  0.2168, -0.5035,  ..., -0.3581, -0.1630,  0.5610],
#         [ 0.0059,  0.0920,  0.2767,  ..., -0.0473,  0.2870,  0.1185]])

# %% [markdown]
# ## Implementing Dot-Product Attention

# %% [markdown]
# Implement a class to perform the dot-product attention ...

# %%
import deeplay as dl

class DotProductAttention(dl.DeeplayModule):
    """Dot-product attention."""

    def __init__(self):
        """Initialize dot-product attention."""
        super().__init__()

    def forward(self, queries, keys, values):
        """Calculate dot-product attention."""
        attn_scores = (torch.matmul(queries, keys.transpose(-2, -1))
                       / (keys.size(-1) ** 0.5))
        attn_matrix = torch.nn.functional.softmax(attn_scores, dim=-1)
        attn_output = torch.matmul(attn_matrix, values)
        return attn_output, attn_matrix

# %% [markdown]
# ... calculate attention matrix and attention output ...

# %%
attention = DotProductAttention()
attn_output, attn_matrix = attention(
    queries=query_embeddings, keys=key_embeddings, values=key_embeddings,
)

# %% [markdown]
# ... implement a function to plot an attention matrix ...

# %%
from matplotlib import pyplot as plt
from matplotlib.ticker import FixedLocator

def plot_attention(query_tokens, key_tokens, attn_matrix):
    """Plot attention."""
    fig, ax = plt.subplots()
    cax = ax.matshow(attn_matrix, cmap="Greens")
    fig.colorbar(cax)
    ax.xaxis.set_major_locator(FixedLocator(range(len(key_tokens))))
    ax.yaxis.set_major_locator(FixedLocator(range(len(query_tokens))))
    ax.set_xticklabels(key_tokens, rotation=90)
    ax.set_yticklabels(query_tokens)
    plt.show()

# %% [markdown]
# ... and use it to plot the attention matrix.

# %%
plot_attention(query_tokens, key_tokens, attn_matrix.detach().squeeze())

# %% [markdown]
# ## Making the Attention Mechanism Trainable

# %% [markdown]
# Implement a class to perform a trainable dot-product attention ...

# %%
class TrainableAttention(dl.DeeplayModule):
    """Trainable dot-product attention."""

    def __init__(self, num_in_features=300, num_out_features=256):
        """Initialize dot-product attention."""
        super().__init__()
        self.Wq = torch.nn.Linear(num_in_features, num_out_features)
        self.Wk = torch.nn.Linear(num_in_features, num_out_features)
        self.Wv = torch.nn.Linear(num_in_features, num_out_features)

    def forward(self, queries, keys, values):
        """Calculate dot-product attention with linear transformations."""
        Q, K, V = self.Wq(queries), self.Wk(keys), self.Wv(values)
        attn_scores = (torch.matmul(Q, K.transpose(-2, -1))
                       / (K.size(-1) ** 0.5))
        attn_matrix = torch.nn.functional.softmax(attn_scores, dim=-1)
        attn_output = torch.matmul(attn_matrix, V)
        return attn_output, attn_matrix

# %% [markdown]
# ... calculate it ...

# %%
trainable_attention = TrainableAttention()
trainable_attn_output, trainable_attn_matrix = trainable_attention(
    queries=query_embeddings, keys=key_embeddings, values=key_embeddings,
)

# %% [markdown]
# ... and plot the resulting attention matrix.

# %%
plot_attention(query_tokens, key_tokens,
               trainable_attn_matrix.detach().squeeze())

# %% [markdown]
# ## Implementing Additive Attention

# %% [markdown]
# Implement a class to perform additive attention ...

# %%
class AdditiveAttention(dl.DeeplayModule):
    """Additive attention."""

    def __init__(self, num_in_features=300, num_out_features=256):
        """Initialize additive attention."""
        super().__init__()
        self.Wq = torch.nn.Linear(num_in_features, num_out_features)
        self.Wk = torch.nn.Linear(num_in_features, num_out_features)
        self.Ws = torch.nn.Linear(num_out_features, 1)

    def forward(self, queries, keys, values):
        """Calculate additive attention."""
        Q, K = self.Wq(queries), self.Wk(keys)
        attn_scores = self.Ws(
            torch.tanh(Q.unsqueeze(-2) + K.unsqueeze(-3))
        ).squeeze(-1)
        attn_matrix = torch.nn.functional.softmax(attn_scores, dim=-1)
        attn_output = torch.matmul(attn_matrix, values)
        return attn_output, attn_matrix

# %% [markdown]
# ... calculate it ...

# %%
additive_attention = AdditiveAttention()
additive_attn_output, additive_attn_matrix = additive_attention(
    queries=query_embeddings, keys=key_embeddings, values=key_embeddings,
)

# %% [markdown]
# ... and plot the resulting attention matrix.

# %%
plot_attention(query_tokens, key_tokens,
               additive_attn_matrix.detach().squeeze())
